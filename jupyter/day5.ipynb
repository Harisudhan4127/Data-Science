# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd 
print("Day-5")
# Out:
# Day-5

# %%
iris = sns.load_dataset('iris')
iris['species'].unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
iris.shape
# Out:
# (150, 5)

# %%
# KNN - K-Nearest Neighbors
sns.pairplot(iris, hue = 'species')
plt.show()

# %%
sns.swarmplot(iris)
plt.show()
# Out:
# C:\Users\STUDENT\anaconda3\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 20.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\STUDENT\anaconda3\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 6.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\STUDENT\anaconda3\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 15.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\STUDENT\anaconda3\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 27.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# ...

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
iris = sns.load_dataset('iris')

x = iris.iloc[:,0:4]
y = iris.iloc[:, 4]
# x= iris[['sepal_length','sepal_width','petal_length','petal_width']]
# y = iris['species']

# print(x)
# print(y)

x_train , x_test, y_train, y_test = train_test_split(x,y,test_size= 0.2)
# training qns, exam qns, training ans, exam ans

# print(x_train.shape)
# print(y_train.shape)

print(x_train.head())

knn = KNeighborsClassifier()
knn.fit(x_train , y_train)
prediction = knn.predict(x_test)
prediction
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 112           6.8          3.0           5.5          2.1
# 55            5.7          2.8           4.5          1.3
# 103           6.3          2.9           5.6          1.8
# 139           6.9          3.1           5.4          2.1
# 51            6.4          3.2           4.5          1.5
# array(['virginica', 'setosa', 'setosa', 'versicolor', 'virginica',
#        'virginica', 'virginica', 'virginica', 'setosa', 'versicolor',
#        'setosa', 'versicolor', 'setosa', 'setosa', 'virginica',
#        'virginica', 'virginica', 'virginica', 'versicolor', 'setosa',
#        'virginica', 'versicolor', 'setosa', 'setosa', 'virginica',
#        'versicolor', 'setosa', 'versicolor', 'setosa', 'setosa'],
#       dtype=object)

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.metrics  import accuracy_score

student = {
    'hours_studied' : [1,2,3,4,5,6,7,8,9],
    'marks_scored' : [35,47,53,62,71,77,82,86,89]
}

student_df = pd.DataFrame(student)
print(student_df.head())

X = student_df[['hours_studied']]
y = student_df['marks_scored']

lr = LinearRegression()
lr.fit(X,y)

print(lr.fit(X,y))

mini_data={
    'hours_studied' : [5]
}
mini_df= pd.DataFrame(mini_data)

predication = lr.predict(mini_df[['hours_studied']])
predication
# Out:
#    hours_studied  marks_scored
# 0              1            35
# 1              2            47
# 2              3            53
# 3              4            62
# 4              5            71
# LinearRegression()
# array([66.88888889])

# %%
import seaborn as sns
tips_df = sns.load_dataset('tips')
tips_df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips_df['day'].unique()
# Out:
# ['Sun', 'Sat', 'Thur', 'Fri']
# Categories (4, object): ['Thur', 'Fri', 'Sat', 'Sun']

# %%
tips_df['time'].unique()
# Out:
# ['Dinner', 'Lunch']
# Categories (2, object): ['Lunch', 'Dinner']

# %%
X = tips_df[["total_bill"]]
y = tips_df["tip"]

# %%
tips_df.shape
# Out:
# (244, 7)

# %%
from sklearn.model_selection import train_test_split
X_train , X_test,y_train ,y_test = train_test_split(X,y,test_size =0.25,random_state =42)

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(X_train,y_train)
predictions = lr.predict(X_test)
# Out:
# array([3.03019394, 1.82116362, 3.54772457, 3.69434001, 2.28398699,
#        2.81902394, 3.97334701, 2.22709145, 2.47874482, 2.54439352,
#        2.86278974, 2.03999264, 2.0268629 , 2.44592046, 1.96340248,
#        2.90108482, 2.90874384, 3.22276348, 2.66146705, 5.368382  ,
#        3.12538456, 3.12100798, 2.42732   , 1.90650694, 3.14836161,
#        2.14065398, 1.98528538, 3.62759716, 2.66584363, 6.13209527,
#        5.02700873, 1.70846667, 2.81027078, 3.08161876, 2.71836259,
#        3.49629975, 2.17785492, 5.57845785, 2.30149331, 3.34202529,
#        2.01154486, 2.45029704, 3.48207586, 1.99185025, 1.9929444 ,
#        1.19750092, 2.02029803, 2.90655555, 1.68877206, 2.31462305,
#        3.51708851, 3.84642618, 4.33113245, 2.61004223, 2.99408715,
#        2.28726943, 1.65485357, 2.81136492, 2.7500928 , 2.57831202,
#        4.12762147])

# %%
import matplotlib.pyplot as plt
plt.scatter(X_train,y_train,color="green",label="Actual data")
plt.plot(X_test,predictions,color="blue",label="Regression line(predicted values")
plt.xlabel("total bill")
plt.ylabel("tips")
plt.title("Linear regression for tips dataset")
plt.legend()
plt.show()
